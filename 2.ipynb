# %% [markdown]
# ### О задании
# На сайтах для поиска работы можно найти сотни тысяч объявлений, каждое из которых состоит из пространного описания вакансии и предлагаемой зарплаты. Есть ли связь между описанием и зарплатой? Существуют ли определенные слова, которые наиболее сильно характеризуют зарплату? Можно ли найти другие информативные факторы? Вам предстоит ответить на эти вопросы, проанализировав выборку объявлений о работе в Великобритании.
#
# Практическое задание 2 посвящено работе с текстовыми данными и категориальными признаками и задачам бинарной классификации. Вы научитесь:
#  * работать с категориальными признаками;
#  * строить вещественные представления текстовых данных;
#  * обучать и строить прогнозы линейных классификаторов при помощи scikit-learn и Vowpal Wabbit;
#  * тестировать модели и проводить оценку качества в задачах бинарной классификации.
#
#
# ### Оценивание и штрафы
#
# Каждая из задач имеет определенную «стоимость» (указана в скобках около задачи). Максимально допустимая оценка за работу — 10 баллов. Кроме того, некоторые из заданий являются опциональными (необязательными), однако за их выполнение можно получить дополнительные баллы, которые позднее будут учитываться при проставлении оценок автоматом по курсу.
#
# Сдавать задание после указанного срока сдачи нельзя. При выставлении неполного балла за задание в связи с наличием ошибок на усмотрение проверяющего предусмотрена возможность исправить работу на указанных в ответном письме условиях.
#
# Задание выполняется самостоятельно. «Похожие» решения считаются плагиатом и все задействованные студенты (в том числе те, у кого списали) не могут получить за него больше 0 баллов (подробнее о плагиате см. на странице курса). Если вы нашли решение какого-то из заданий (или его часть) в открытом источнике, необходимо указать ссылку на этот источник в отдельном блоке в конце Вашей работы (скорее всего вы будете не единственным, кто это нашел, поэтому чтобы исключить подозрение в плагиате, необходима ссылка на источник).
#
# Неэффективная реализация кода может негативно отразиться на оценке.

# %% [markdown]
# ## Данные
#
# Как было упомянуто ранее, в рамках данного задания мы будем решать задачу бинарной классификации для предсказания уровня заработной платы по тексту объявления о вакансии на примере набора данных с соревнования [Adzuna - Job Salary Prediction](https://www.kaggle.com/c/job-salary-prediction). Для начала пройдите по [ссылке](https://www.kaggle.com/c/job-salary-prediction/data) и скачайте файл Train_rev1 (при необходимости, зарегистрируйтесь на Kaggle).
#
# Посмотрим на данные в файле и загрузим их в DataFrame:

# %%
# %pylab inline

import pandas as pd
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# print first 2 rows from Train_rev1.csv
# !head -n 2 Train_rev1.csv
# Out:
# Id,Title,FullDescription,LocationRaw,LocationNormalized,ContractType,ContractTime,Company,Category,SalaryRaw,SalaryNormalized,SourceName
# 12612628,Engineering Systems Analyst,"Engineering Systems Analyst Dorking Surrey Salary ****K Our client is located in Dorking, Surrey and are looking for Engineering Systems Analyst our client provides specialist software development Keywords Mathematical Modelling, Risk Analysis, System Modelling, Optimisation, MISER, PIONEEER Engineering Systems Analyst Dorking Surrey Salary ****K","Dorking, Surrey, Surrey",Dorking,,permanent,Gregory Martin International,Engineering Jobs,20000 - 30000/annum 20-30K,25000,cv-library.co.uk

# %%
df = pd.read_csv('Train_rev1.csv', sep=',')
print(df.shape)
df.head()
# Out:
# (244768, 12)
#          Id                                              Title  \
# 0  12612628                        Engineering Systems Analyst
# 1  12612830                            Stress Engineer Glasgow
# 2  12612844                   Modelling and simulation analyst
# 3  12613049  Engineering Systems Analyst / Mathematical Mod...
# 4  12613647         Pioneer, Miser Engineering Systems Analyst
#
#                                      FullDescription  \
# 0  Engineering Systems Analyst Dorking Surrey Sal...
# 1  Stress Engineer Glasgow Salary **** to **** We...
# 2  Mathematical Modeller / Simulation Analyst / O...
# 3  Engineering Systems Analyst / Mathematical Mod...
# 4  Pioneer, Miser  Engineering Systems Analyst Do...
#
#                          LocationRaw LocationNormalized ContractType  \
# 0            Dorking, Surrey, Surrey            Dorking          NaN
# 1        Glasgow, Scotland, Scotland            Glasgow          NaN
# 2  Hampshire, South East, South East          Hampshire          NaN
# 3     Surrey, South East, South East             Surrey          NaN
# 4     Surrey, South East, South East             Surrey          NaN
#
#   ContractTime                       Company          Category  \
# 0    permanent  Gregory Martin International  Engineering Jobs
# 1    permanent  Gregory Martin International  Engineering Jobs
# 2    permanent  Gregory Martin International  Engineering Jobs
# 3    permanent  Gregory Martin International  Engineering Jobs
# 4    permanent  Gregory Martin International  Engineering Jobs
#
#                                 SalaryRaw  SalaryNormalized        SourceName
# 0              20000 - 30000/annum 20-30K             25000  cv-library.co.uk
# 1              25000 - 35000/annum 25-35K             30000  cv-library.co.uk
# 2              20000 - 40000/annum 20-40K             30000  cv-library.co.uk
# 3  25000 - 30000/annum 25K-30K negotiable             27500  cv-library.co.uk
# 4              20000 - 30000/annum 20-30K             25000  cv-library.co.uk

# %% [markdown]
# В оригинальной постановке предлагается рассматривать признак SalaryNormalized как целевой и решать задачу регрессии, однако в рамках данного задания мы сведём её к задаче бинарной классификации, разделив объекты на 2 группы: объявления о вакансиях с низкой и высокой зарплатами соответственно.
#
# <img src = "http://salt.uaa.alaska.edu/kath/kti/mean_median2.gif">
#
# В качестве порога разбиения объектов на группы будем рассматривать медиану признака SalaryNormalized. Заметим, что таким образом мы автоматически получим задачу классификации со сбалансированными классами:

# %%
# salary histogramm
median = np.median(df['SalaryNormalized'])

figsize(16,8)
plt.hist(df['SalaryNormalized'], bins=50)
plt.axvline(median, c='r')
plt.xlabel('salary', fontsize=20)
plt.ylabel('count', fontsize=20)
plt.grid()

# %% [markdown]
# Осуществим последние шаги по подготовке датасета:
# - бинаризуем признак SalaryNomalized по описанному ранее порогу;
# - исключим из выборки признак SalaryRaw, чтобы устранить утечку целевой переменной в признаки.

# %%
df['SalaryNormalized'] = (df['SalaryNormalized'] > median).astype(int)
df.drop('SalaryRaw', axis=1, inplace=True)
df.head()
# Out:
#          Id                                              Title  \
# 0  12612628                        Engineering Systems Analyst
# 1  12612830                            Stress Engineer Glasgow
# 2  12612844                   Modelling and simulation analyst
# 3  12613049  Engineering Systems Analyst / Mathematical Mod...
# 4  12613647         Pioneer, Miser Engineering Systems Analyst
#
#                                      FullDescription  \
# 0  Engineering Systems Analyst Dorking Surrey Sal...
# 1  Stress Engineer Glasgow Salary **** to **** We...
# 2  Mathematical Modeller / Simulation Analyst / O...
# 3  Engineering Systems Analyst / Mathematical Mod...
# 4  Pioneer, Miser  Engineering Systems Analyst Do...
#
#                          LocationRaw LocationNormalized ContractType  \
# 0            Dorking, Surrey, Surrey            Dorking          NaN
# 1        Glasgow, Scotland, Scotland            Glasgow          NaN
# 2  Hampshire, South East, South East          Hampshire          NaN
# 3     Surrey, South East, South East             Surrey          NaN
# 4     Surrey, South East, South East             Surrey          NaN
#
#   ContractTime                       Company          Category  \
# 0    permanent  Gregory Martin International  Engineering Jobs
# 1    permanent  Gregory Martin International  Engineering Jobs
# 2    permanent  Gregory Martin International  Engineering Jobs
# 3    permanent  Gregory Martin International  Engineering Jobs
# 4    permanent  Gregory Martin International  Engineering Jobs
#
#    SalaryNormalized        SourceName
# 0                 0  cv-library.co.uk
# 1                 0  cv-library.co.uk
# 2                 0  cv-library.co.uk
# 3                 0  cv-library.co.uk
# 4                 0  cv-library.co.uk

# %% [markdown]
# #### 1. (0 баллов) Разбейте получившуюся выборку на обучающую и контрольную в соотношении 70/30 с использованием перемешивания объектов.
#
# При разбиении используйте значение параметра random_state=42.

# %%
from sklearn.model_selection import train_test_split

train, test = train_test_split(df,test_size=0.3, random_state = 42)

c = ['LocationNormalized', 'ContractType', 'ContractTime', 'Category', 'SourceName', 'Company']

Y_train = train['SalaryNormalized']
Y_test = test['SalaryNormalized']

#need more than 30gb ram
#text = df[['Title', 'FullDescription','LocationNormalized', 'ContractType', 'ContractTime', 'Company']].apply(lambda x: ' '.join(x.astype(str)), axis=1)

cols = df[c].apply(lambda x: ' '.join(x.astype(str)), axis=1)
train.head()
# Out:
#               Id                                             Title  \
# 241453  72676065  Business Development Executive  ****k plus bonus
# 169520  71341050                                   English Teacher
# 136661  70336585         EMEA Customer Service Project Coordinator
# 125435  69992269                      Administrator / Receptionist
# 192568  71760157        Business Analyst / Product Owner  to ****k
#
#                                           FullDescription  \
# 241453  Business Development Executive Dudley Permanen...
# 169520  English Teacher  Permanent, Fulltime contract ...
# 136661  Excellent opportunity to join a successful glo...
# 125435  Acting as a recruitment business on behalf of ...
# 192568  Business Analyst / Product Owner This is an ex...
#
#                                               LocationRaw LocationNormalized  \
# 241453  Dudley, West Midlands (County) West Midlands (...                 UK
# 169520                                               Avon               Avon
# 136661                                             Oxford             Oxford
# 125435                     Leeds West Yorkshire Yorkshire              Leeds
# 192568                                  London South East  South East London
#
#        ContractType ContractTime                     Company  \
# 241453          NaN    permanent    Anderson Scott Solutions
# 169520    full_time     contract  ITN Mark Education Bristol
# 136661    full_time          NaN      Bluestream Recruitment
# 125435          NaN     contract                  Taskmaster
# 192568          NaN    permanent           The Industry Club
#
#                       Category  SalaryNormalized             SourceName
# 241453              Sales Jobs                 0          totaljobs.com
# 169520           Teaching Jobs                 0  jobsineducation.co.uk
# 136661  Customer Services Jobs                 0      careerbuilder.com
# 125435              Admin Jobs                 0          totaljobs.com
# 192568                 IT Jobs                 1           cwjobs.co.uk

# %% [markdown]
# ## Векторизация
#
# Как правило, модели, используемые в машинном обучении, применяются в предположении, что матрица "объект-признак" является вещественнозначной. Поэтому при работе с категориальными признаками и текстами сперва их необходимо привести к вещественному виду.
#
# Заметим, что в нашей задаче есть признаки, являющиеся текстами произвольной природы (Title, FullDescription), и категориальные признаки, принимающие ограниченное число значений (ContractType, Category и др.).
#
# Самый простой и понятный способ преобразования текстовых данных — векторизация. В этом случае для каждого слова, встречающегося в некотором набре текстов мы создаём отдельный новый признак, который будет равен $1$, когда слово встречается в заданном объекте, и $0$ – в противном случае.
#
# #### 2. (0.5 балла) Создайте текстовое описание объектов обучающей и контрольной выборок, объединив значения всех признаков каждого объекта выборки через символы пробела. После этого получите признаковое описание объектов, осуществив векторизацию получившихся текстов при помощи [CountVectorizer](http://scikit-learn.org/stable/modules/generated/sklearn.feature_extraction.text.CountVectorizer.html), обучив его на обучающей выборке и применив на контрольной.

# %%
from sklearn.feature_extraction.text import CountVectorizer
vectorizer = CountVectorizer()
vectorizer.fit(cols)

cols_train = train[c].apply(lambda x: ' '.join(x.astype(str)), axis=1)
cols_test = test[c].apply(lambda x: ' '.join(x.astype(str)), axis=1)

X_train = vectorizer.transform(cols_train)
X_test = vectorizer.transform(cols_test)

print(X_train.shape) 
vectorizer.vocabulary_
# Out:
# (171337, 13958)
# {'dorking': 3862,
#  'nan': 8775,
#  'permanent': 9670,
#  'engineering': 4331,
#  'jobs': 6861,
#  'cv': 3439,
#  'library': 7540,
#  'co': 2826,
#  'uk': 12972,
#  'gregory': 5564,
#  'martin': 8068,
#  'international': 6620,
#  'glasgow': 5342,
#  'hampshire': 5728,
#  'surrey': 12167,
#  'indigo': 6492,
#  '21': 20,
#  'ltd': 7808,
#  'manchester': 7980,
#  'hr': 6288,
#  'recruitment': 10475,
#  'code': 2857,
#  'blue': 1569,
#  'leeds': 7460,
#  'aberdeen': 114,
#  'east': 4058,
#  'midlands': 8401,
#  'accounting': 187,
#  'finance': 4804,
#  'brite': 1848,
#  'witney': 13690,
#  'healthcare': 5919,
#  'nursing': 9100,
#  'matchbox': 8107,
#  'recruiting': 10474,
#  'avon': 1020,
#  'other': 9333,
#  'general': 5258,
#  'derby': 3672,
#  'hospitality': 6244,
#  'catering': 2344,
#  'caterer': 2340,
#  'com': 2929,
#  'chef': 2532,
#  'results': 10667,
#  'gateshead': 5222,
#  'asset': 873,
#  'appointments': 712,
#  'kent': 7077,
#  'wolverhampton': 13712,
#  'rullion': 10954,
#  'towngate': 12735,
#  'personnel': 9683,
#  'berkshire': 1379,
#  'north': 9020,
#  'england': 4333,
#  'clear': 2739,
#  'selection': 11258,
#  'yorkshire': 13911,
#  'sheen': 11375,
#  'bee': 1300,
#  'london': 7730,
#  'buckinghamshire': 1967,
#  'chess': 2561,
#  'partnership': 9496,
#  'it': 6713,
#  'central': 2414,
#  'york': 13910,
#  'newcastle': 8897,
#  'upon': 13038,
#  'tyne': 12947,
#  'cambridge': 2136,
#  'contract': 3079,
#  'customer': 3429,
#  'services': 11309,
#  'gloucestershire': 5380,
#  'bushey': 2029,
#  'travel': 12792,
#  'leisurejobs': 7480,
#  'hertsmere': 6013,
#  'leisure': 7479,
#  'kirklees': 7201,
#  'active': 223,
#  'sarratt': 11090,
#  'brunning': 1937,
#  'price': 10044,
#  'milford': 8422,
#  'maidstone': 7934,
#  'sales': 11028,
#  'bradford': 1718,
#  'burgess': 2005,
#  'hill': 6070,
#  'birmingham': 1488,
#  'lingfield': 7591,
#  'full_time': 5113,
#  'zartis': 13933,
#  'inspire': 6564,
#  'corporation': 3156,
#  'derbyshire': 3673,
#  'didsbury': 3738,
#  'marston': 8063,
#  'inns': 6550,
#  'and': 610,
#  'taverns': 12346,
#  'south': 11711,
#  'leicestershire': 7474,
#  'ipswich': 6675,
#  'catererandhotelkeeper': 2341,
#  'manufacturing': 8006,
#  'the': 12508,
#  'city': 2682,
#  'hays': 5886,
#  'staffordshire': 11871,
#  'theitjobboard': 12520,
#  'suffolk': 12112,
#  'norfolk': 9013,
#  'haywards': 5889,
#  'heath': 5931,
#  'jersey': 6813,
#  'marshall': 8059,
#  'human': 6316,
#  'resources': 10648,
#  'teaching': 12381,
#  'vision': 13234,
#  'for': 4956,
#  'education': 4153,
#  'nottinghamshire': 9055,
#  'northamptonshire': 9024,
#  'essex': 4445,
#  'welwyn': 13471,
#  'garden': 5200,
#  'woodbridge': 13721,
#  'hertfordshire': 6011,
#  'milton': 8445,
#  'keynes': 7105,
#  'bristol': 1843,
#  'basingstoke': 1220,
#  'warrington': 13356,
#  'west': 13487,
#  'regent': 10557,
#  'salisbury': 11033,
#  'canterbury': 2182,
#  'andy': 620,
#  'file': 4793,
#  'associates': 883,
#  'middleton': 8396,
#  'f1rst': 4623,
#  'commercial': 2938,
#  'op': 9237,
#  'serata': 11295,
#  'search': 11208,
#  'creative': 3280,
#  'design': 3682,
#  'burton': 2022,
#  'on': 9216,
#  'trent': 12815,
#  'blues': 1583,
#  'point': 9880,
#  'efinancialcareers': 4167,
#  'excelsior': 4549,
#  'professional': 10106,
#  'poole': 9910,
#  'cumbria': 3409,
#  'rengineeringjobs': 10610,
#  'randstad': 10373,
#  'tring': 12837,
#  'champneys': 2473,
#  'health': 5918,
#  'resort': 10643,
#  'bath': 1227,
#  'henlow': 5986,
#  'oxford': 9375,
#  'trade': 12754,
#  'construction': 3051,
#  'works': 13774,
#  'carnegie': 2270,
#  'consulting': 3063,
#  'huddersfield': 6306,
#  'rotherham': 10886,
#  'sourcedogg': 11708,
#  'sussex': 12174,
#  'careworx': 2248,
#  'norwich': 9047,
#  'cardiff': 2213,
#  'bury': 2024,
#  'st': 11855,
#  'edmunds': 4146,
#  'braintree': 1731,
#  'nottingham': 9054,
#  'driffield': 3921,
#  'edinburgh': 4135,
#  'blyth': 1593,
#  'winchester': 13640,
#  'part_time': 9489,
#  'durham': 4000,
#  'sunderland': 12129,
#  'pembrokeshire': 9590,
#  'southampton': 11714,
#  'bournemouth': 1681,
#  'boston': 1664,
#  'leicester': 7473,
#  'hull': 6314,
#  'shrewsbury': 11448,
#  'rugby': 10951,
#  'clevedon': 2763,
#  'scotland': 11163,
#  'gainsborough': 5173,
#  'hadleigh': 5671,
#  'totnes': 12719,
#  'oxfordshire': 9376,
#  'harlow': 5790,
#  'woking': 13701,
#  'dundee': 3980,
#  'fife': 4789,
#  'inverness': 6649,
#  'hatherleigh': 5845,
#  'frome': 5082,
#  'devon': 3706,
#  'torquay': 12707,
#  'exeter': 4565,
#  'aylesbury': 1040,
#  'sutton': 12178,
#  'green': 5528,
#  'whitby': 13551,
#  'preston': 10034,
#  'southport': 11725,
#  'looe': 7753,
#  'bramhope': 1734,
#  'lancashire': 7321,
#  'slough': 11591,
#  'brighton': 1823,
#  'ilkley': 6448,
#  'skipton': 11570,
#  'daventry': 3547,
#  'newton': 8926,
#  'abbot': 105,
#  'cambridgeshire': 2137,
#  'liverpool': 7642,
#  'cheshire': 2559,
#  'chobham': 2614,
#  'chorley': 2621,
#  'burnley': 2017,
#  'whittlebury': 13574,
#  'marton': 8074,
#  'in': 6473,
#  'cleveland': 2764,
#  'silsden': 11483,
#  'edwalton': 4158,
#  'molton': 8523,
#  'chelmsford': 2539,
#  'maldon': 7953,
#  'southend': 11719,
#  'sea': 11192,
#  'brentwood': 1785,
#  'colchester': 2877,
#  'clacton': 2699,
#  'paignton': 9407,
#  'brixham': 1856,
#  'watford': 13390,
#  'potters': 9957,
#  'bar': 1155,
#  'borehamwood': 1656,
#  'harrow': 5811,
#  'brent': 1782,
#  'cross': 3337,
#  'bexley': 1417,
#  'saxmundham': 11109,
#  'ashton': 843,
#  'under': 12992,
#  'lyne': 7845,
#  'hereford': 5994,
#  'dumfries': 3971,
#  'middlesbrough': 8395,
#  'northampton': 9023,
#  'ormskirk': 9307,
#  'ilfracombe': 6446,
#  'sidmouth': 11460,
#  'eastbourne': 4059,
#  'redhill': 10513,
#  'horsham': 6235,
#  'perth': 9687,
#  'high': 6051,
#  'wycombe': 13830,
#  'reading': 10433,
#  'epsom': 4393,
#  'crawley': 3266,
#  'kendal': 7064,
#  'thetford': 12531,
#  'lowestoft': 7790,
#  'hingham': 6093,
#  'mold': 8515,
#  'callington': 2123,
#  'marlow': 8053,
#  'lincolnshire': 7582,
#  'arbroath': 741,
#  'guildford': 5627,
#  'worthing': 13793,
#  'witham': 13682,
#  'basildon': 1219,
#  'dunmow': 3989,
#  'bolton': 1626,
#  'uttoxeter': 13069,
#  'weymouth': 13524,
#  'bridport': 1810,
#  'lyme': 7838,
#  'regis': 10562,
#  'dorchester': 3861,
#  'swanage': 12190,
#  'beaminster': 1268,
#  'wool': 13748,
#  'fagans': 4649,
#  'cayton': 2370,
#  'bay': 1238,
#  'tavistock': 12347,
#  'lostwithiel': 7767,
#  'aboyne': 140,
#  'hemel': 5972,
#  'hempstead': 5975,
#  'luton': 7825,
#  'bedford': 1295,
#  'doncaster': 3847,
#  'turriff': 12915,
#  'wheatley': 13535,
#  'whitehaven': 13558,
#  'egremont': 4174,
#  'deeside': 3614,
#  'wrekin': 13805,
#  'lanarkshire': 7320,
#  'fraserburgh': 5046,
#  'aberdeenshire': 115,
#  'wigan': 13591,
#  'edgware': 4132,
#  'gloucester': 5379,
#  'peterhead': 9700,
#  'chipping': 2603,
#  'norton': 9044,
#  'ayrshire': 1045,
#  'gravesend': 5514,
#  'bedfordshire': 1296,
#  'swindon': 12211,
#  'aldringham': 440,
#  'shropshire': 11450,
#  'ilford': 6445,
#  'bromsgrove': 1891,
#  'sheffield': 11377,
#  'blackpool': 1524,
#  'stourport': 12031,
#  'severn': 11323,
#  'droylsden': 3939,
#  'mottram': 8639,
#  'sawston': 11106,
#  'ely': 4251,
#  'burwell': 2023,
#  'yarnton': 13882,
#  'leonards': 7494,
#  'coventry': 3214,
#  'borders': 1654,
#  'stirling': 11978,
#  'stockport': 11989,
#  'tunbridge': 12906,
#  'wells': 13466,
#  'dartford': 3524,
#  'chalfont': 2460,
#  'giles': 5307,
#  'hayes': 5878,
#  'sandwich': 11067,
#  'oxted': 9379,
#  'cheltenham': 2541,
#  'scunthorpe': 11185,
#  'newport': 8913,
#  'bideford': 1439,
#  'dunstable': 3994,
#  'houghton': 6262,
#  'ampthill': 587,
#  'sandy': 11068,
#  'stroud': 12081,
#  'lambeth': 7313,
#  'ottershaw': 9340,
#  'margate': 8028,
#  'henley': 5985,
#  'thames': 12502,
#  'edgbaston': 4127,
#  'workington': 13768,
#  'walsham': 13324,
#  'bagshot': 1075,
#  'barnsley': 1192,
#  'nantwich': 8785,
#  'corby': 3132,
#  'martock': 8073,
#  'brecon': 1774,
#  'cwmbran': 3450,
#  'taunton': 12344,
#  'andover': 616,
#  'burntwood': 2020,
#  'ashtead': 842,
#  'chester': 2563,
#  'angus': 631,
#  'stoke': 11996,
#  'ealing': 4043,
#  'solihull': 11668,
#  'folkestone': 4944,
#  'kentish': 7079,
#  'town': 12734,
#  'buxton': 2041,
#  'oswestry': 9332,
#  'bromwich': 1892,
#  'chichester': 2573,
#  'pitlochry': 9798,
#  'widnes': 13590,
#  'shipton': 11421,
#  'wychwood': 13829,
#  'cardigan': 2214,
#  'bordon': 1655,
#  'sevenoaks': 11322,
#  'northumberland': 9038,
#  'lampeter': 7315,
#  'ashford': 838,
#  'campbeltown': 2153,
#  'southwark': 11728,
#  'oldham': 9196,
#  'sherborne': 11395,
#  'blairgowrie': 1532,
#  'uckfield': 12966,
#  'stowmarket': 12034,
#  'honiton': 6203,
#  'ottery': 9341,
#  'mary': 8078,
#  'cranleigh': 3261,
#  'paisley': 9409,
#  'ebbw': 4083,
#  'vale': 13083,
#  'christchurch': 2627,
#  'halifax': 5695,
#  'arundel': 805,
#  'gosport': 5459,
#  'amersham': 569,
#  'hanley': 5752,
#  'exmouth': 4573,
#  'devizes': 3705,
#  'crewe': 3302,
#  'fareham': 4684,
#  'wallasey': 13313,
#  'leyland': 7526,
#  'cornwall': 3151,
#  'portsmouth': 9946,
#  'washington': 13364,
#  'walsall': 13321,
#  'stafford': 11869,
#  'dudley': 3963,
#  'chorlton': 2622,
#  'cum': 3406,
#  'hardy': 5775,
#  'cheadle': 2524,
#  'wales': 13305,
#  'holmfirth': 6170,
#  'skelmersdale': 11544,
#  'shields': 11408,
#  'farnborough': 4694,
#  'tadley': 12266,
#  'woodley': 13737,
#  'bracknell': 1716,
#  'halesowen': 5689,
#  'prescot': 10020,
#  'somerset': 11686,
#  'barnstaple': 1193,
#  'great': 5525,
#  'missenden': 8473,
#  'bromley': 1889,
#  'cowley': 3220,
#  'neath': 8831,
#  'port': 9924,
#  'talbot': 12286,
#  'flintshire': 4906,
#  'llandaff': 7655,
#  'prudhoe': 10180,
#  'belper': 1334,
#  'chesterfield': 2564,
#  'northallerton': 9021,
#  'bingley': 1466,
#  'dunfermline': 3983,
#  'darlington': 3521,
#  'dewsbury': 3712,
#  'altrincham': 530,
#  'bridgwater': 1808,
#  'reigate': 10573,
#  'virginia': 13227,
#  'water': 13374,
#  'dawlish': 3555,
#  'southall': 11712,
#  'weoley': 13479,
#  'castle': 2322,
#  'worcester': 13755,
#  'droitwich': 3936,
#  'worcestershire': 13756,
#  'kirkcaldy': 7196,
#  'lytham': 7857,
#  'redcar': 10504,
#  'sudbury': 12109,
#  'wear': 13426,
#  'croydon': 3353,
#  'stockton': 11991,
#  'tees': 12418,
#  'harrogate': 5810,
#  'histon': 6101,
#  'wimbledon': 13636,
#  'wantage': 13334,
#  'hammersmith': 5722,
#  'merthyr': 8338,
#  'tydfil': 12943,
#  'pontypridd': 9907,
#  'caterham': 2343,
#  'biddulph': 1438,
#  'guisborough': 5632,
#  'lewes': 7518,
#  'romford': 10851,
#  'hove': 6273,
#  'omagh': 9206,
#  'ashbourne': 827,
#  'huyton': 6351,
#  'macclesfield': 7872,
#  'thirsk': 12540,
#  'lincoln': 7581,
#  'ongar': 9225,
#  'stocksfield': 11990,
#  'weybridge': 13523,
#  'ruislip': 10953,
#  'malvern': 7966,
#  'wrexham': 13808,
#  'huntingdon': 6334,
#  'clayton': 2728,
#  'calne': 2127,
#  'henfield': 5982,
#  'dover': 3880,
#  'midhurst': 8399,
#  'stratford': 12052,
#  'bodmin': 1615,
#  'tewkesbury': 12483,
#  'monmouth': 8542,
#  'okehampton': 9188,
#  'thamesmead': 12504,
#  'bognor': 1620,
#  'mansfield': 7997,
#  'fleet': 4893,
#  'richmond': 10726,
#  'hackney': 5664,
#  'bacup': 1065,
#  'largs': 7361,
#  'gillingham': 5311,
#  'hatfield': 5843,
#  'chingford': 2599,
#  'wakefield': 13300,
#  'kettering': 7096,
#  'llandrindod': 7658,
#  'riding': 10738,
#  'rhyl': 10715,
#  'yeovil': 13897,
#  'lymington': 7839,
#  'pontefract': 9902,
#  'bangor': 1139,
#  'trident': 12829,
#  'bourne': 1680,
#  'colwyn': 2927,
#  'southsea': 11726,
#  'waltham': 13328,
#  'abbey': 101,
#  'barnet': 1187,
#  'rushden': 10966,
#  'xl': 13864,
#  'property': 10141,
#  'onestep': 9222,
#  'leiston': 7478,
#  'stevenage': 11962,
#  'attleborough': 944,
#  'morecambe': 8584,
#  'merseyside': 8337,
#  'leighton': 7476,
#  'buzzard': 2043,
#  'minehead': 8450,
#  'bexhill': 1416,
#  'upminster': 13037,
#  'wishaw': 13678,
#  'smethwick': 11608,
#  'dartmouth': 3527,
#  'dymock': 4024,
#  'littlehampton': 7636,
#  'carlisle': 2258,
#  'dursley': 4003,
#  'runcorn': 10955,
#  'bathgate': 1228,
#  'stourbridge': 12030,
#  'tamworth': 12305,
#  'kidlington': 7127,
#  'securityclearedjobs': 11237,
#  'saltash': 11039,
#  'sidcup': 11458,
#  'oilcareers': 9187,
#  'multi': 8697,
#  'project': 10125,
#  'support': 12152,
#  'isles': 6705,
#  'of': 9166,
#  'scilly': 11152,
#  'haslemere': 5834,
#  'northwich': 9042,
#  'cannock': 2175,
#  'ashby': 831,
#  'de': 3582,
#  'la': 7279,
#  'zouch': 13955,
#  'waterlooville': 13384,
#  'powys': 9972,
#  'hampstead': 5729,
#  'cotowork': 3182,
#  'itk': 6727,
#  'admin': 270,
#  'ashington': 839,
#  'square': 11832,
#  'executive': 4560,
#  'dorset': 3869,
#  'march': 8018,
#  'stretford': 12070,
#  'uppingham': 13041,
#  'oakham': 9129,
#  'stamford': 11886,
#  'mayfair': 8149,
#  'liversedge': 7643,
#  'work': 13757,
#  'place': 9812,
#  'group': 5599,
#  'merton': 8339,
#  'multilingualvacancies': 8700,
#  'linguists': 7594,
#  'direct': 3764,
#  'belfast': 1323,
#  'aldford': 433,
#  'bilston': 1459,
#  'banbury': 1130,
#  'weston': 13513,
#  'super': 12138,
#  'mare': 8023,
#  'glastonbury': 5344,
#  'farnham': 4697,
#  'bridgend': 1803,
#  'herefordshire': 5995,
#  'oldbury': 9192,
#  'birkenhead': 1484,
#  'stalybridge': 11885,
#  'shefford': 11378,
#  'eastleigh': 4065,
#  'wiltshire': 13635,
#  'congleton': 3015,
#  'loughborough': 7774,
#  'wellingborough': 13462,
#  'warminster': 13349,
#  'evesham': 4527,
#  'melton': 8290,
#  'mowbray': 8656,
#  'kidderminster': 7123,
#  'liss': 7625,
#  'long': 7734,
#  'stratton': 12057,
#  'legal': 7465,
#  'newbury': 8895,
#  'end': 4313,
#  'spa': 11739,
#  'retail': 10669,
#  'brigg': 1814,
#  'berkhamsted': 1377,
#  'redbourn': 10501,
#  'loudwater': 7773,
#  'lichfield': 7542,
#  'warwick': 13361,
#  'isle': 6704,
#  'wight': 13593,
#  'leigh': 7475,
#  'myjobs': 8751,
#  'cimaglobal': 2655,
#  'cmc': 2818,
#  'limited': 7576,
#  'recruitni': 10483,
#  'array': 787,
#  'new': 8889,
#  'wadhurst': 13292,
#  'buckhurst': 1965,
#  'pembroke': 9589,
#  'hook': 6206,
#  'gold': 5406,
#  'leaf': 7434,
#  'irlam': 6682,
#  'cradley': 3244,
#  'market': 8040,
#  'rasen': 10390,
#  'blaenau': 1530,
#  'gwent': 5652,
#  'cora': 3127,
#  'partners': 9495,
#  'consultancy': 3058,
#  'network': 8876,
#  'employment': 4288,
#  'drayton': 3913,
#  'buckingham': 1966,
#  'scarborough': 11125,
#  'energy': 4319,
#  'oil': 9185,
#  'gas': 5216,
#  't2p': 12255,
#  'billericay': 1453,
#  'deal': 3585,
#  'knutsford': 7243,
#  'jobserve': 6870,
#  'stonewood': 12010,
#  'competition': 2968,
#  'line': 7586,
#  'grinstead': 5580,
#  'bicester': 1435,
#  'gerrards': 5282,
#  'waterloo': 13383,
#  'cressington': 3296,
#  'jobg8': 6857,
#  'castlerock': 2330,
#  'solar': 11661,
#  'matchtech': 8111,
#  'plc': 9848,
#  'cramlington': 3256,
#  'felixstowe': 4748,
#  'esher': 4430,
#  'louth': 7780,
#  'keighley': 7041,
#  'ewell': 4536,
#  'chelsea': 2540,
#  'wallsend': 13318,
#  'camberley': 2132,
#  'tfpl': 12490,
#  'engage': 4324,
#  'chippenham': 2602,
#  'hanover': 5755,
#  'global': 5368,
#  'insurance': 6581,
#  'emerald': 4264,
#  'consett': 3038,
#  'logistics': 7723,
#  'warehouse': 13341,
#  'letchworth': 7500,
#  'armagh': 773,
#  'worksop': 13776,
#  'wokingham': 13702,
#  'cronton': 3332,
#  'salt': 11037,
#  'pepper': 9649,
#  'steakhouse': 11931,
#  'rickmansworth': 10729,
#  'chard': 2491,
#  'westerham': 13494,
#  'king': 7159,
#  'lynn': 7849,
#  'swansea': 12194,
#  'planetrecruit': 9822,
#  'computer': 2986,
#  'consultants': 3060,
#  'atr': 934,
#  'solutions': 11678,
#  'team': 12383,
#  'orion': 9300,
#  'electrotech': 4200,
#  'spectrum': 11766,
#  'lynx': 7851,
#  'concept': 2994,
#  'roger': 10829,
#  'jones': 6902,
#  'amrec': 589,
#  'lothian': 7768,
#  'midlothian': 8402,
#  'migration': 8411,
#  'set2recruit': 11316,
#  'llanbedr': 7653,
#  'dyffryn': 4021,
#  'clwyd': 2811,
#  'forces': 4959,
#  'additional': 249,
#  'antrim': 663,
#  'mass': 8090,
#  'informatiq': 6513,
#  'warwickshire': 13362,
#  'pr': 9984,
#  'advertising': 300,
#  'marketing': 8041,
#  'briskona': 1840,
#  'palm': 9419,
#  'abrecco': 147,
#  'enterprise': 4357,
#  'dms': 3817,
#  'select': 11257,
#  'brook': 1896,
#  'street': 12064,
#  'extech': 4600,
#  '2000': 15,
#  'resource': 10645,
#  'azteq': 1048,
#  'nuepc': 9085,
#  'go': 5395,
#  'argyll': 766,
#  'bute': 2037,
#  'charity': 2500,
#  'voluntary': 13266,
#  'hi': 6044,
#  'calibre': 2115,
#  'excel': 4544,
#  'technical': 12398,
#  'resourcing': 10649,
#  'absolute': 150,
#  'solution': 11677,
#  'hotrecruit': 6258,
#  'wesser': 13485,
#  'language': 7353,
#  'scientific': 11150,
#  'qa': 10252,
#  'alchemy': 420,
#  'w5': 13286,
#  'maintenance': 7943,
#  'jobsinsocialwork': 6877,
#  'cullompton': 3399,
#  'abertillery': 124,
#  'hebburn': 5942,
#  'tadworth': 12267,
#  'carmarthen': 2265,
#  'lancaster': 7322,
#  'catterick': 2358,
#  'ellesmere': 4224,
#  'faversham': 4718,
#  'verwood': 13175,
#  'monmouthshire': 8543,
#  'topnotchresources': 12697,
#  'leamington': 7439,
#  'not': 9049,
#  'disclosed': 3780,
#  'treorchy': 12816,
#  'wilmslow': 13630,
#  'sleaford': 11584,
#  'workthing': 13780,
#  'domestic': 3839,
#  'help': 5963,
#  'cleaning': 2736,
#  'peterborough': 9698,
#  'jobsfinancial': 6871,
#  'career': 2221,
#  'impart': 6461,
#  'thecareerengineer': 12515,
#  'employ': 4285,
#  'staff': 11861,
#  'drivinggb': 3935,
#  'james': 6760,
#  'gray': 5518,
#  'populus': 9920,
#  'jobsineducation': 6874,
#  'talent': 12287,
#  'abc': 107,
#  'teachers': 12379,
#  'plus': 9865,
#  'supply': 12150,
#  'desk': 3686,
#  'directions': 3767,
#  'teachin': 12380,
#  'reeson': 10534,
#  'synarbor': 12234,
#  'key': 7100,
#  'stage': 11877,
#  'people': 9633,
#  'keep': 7034,
#  'smart': 11601,
#  'leek': 7461,
#  'ripley': 10758,
#  'totaljobs': 12715,
#  'charterhouse': 2511,
#  'markfield': 8046,
#  'inhouse': 6531,
#  'wise': 13675,
#  'fradley': 5030,
#  'park': 9465,
#  'simply': 11505,
#  'eastern': 4061,
#  'beaconsfield': 1264,
#  'kingston': 7177,
#  'cheddar': 2528,
#  'borough': 1658,
#  'restaurant': 10660,
#  'quays': 10282,
#  'nijobfinder': 8966,
#  'abacus': 97,
#  'total': 12714,
#  'fundraising': 5123,
#  'grafton': 5489,
#  'ni': 8945,
#  'vanrath': 13106,
#  'northern': 9031,
#  'ireland': 6681,
#  'airport': 383,
#  'cmb': 2817,
#  'friern': 5074,
#  'bargoed': 1169,
#  'brierley': 1812,
#  'stockland': 11988,
#  'kirkby': 7195,
#  'ashfield': 837,
#  'walton': 13330,
#  'addison': 248,
#  'fowle': 5021,
#  'eph': 4384,
#  'macintyre': 7886,
#  'redditch': 10507,
#  'torry': 12709,
#  'peckham': 9574,
#  'grimsby': 5578,
#  'liphook': 7615,
#  'procure': 10095,
#  'uxbridge': 13071,
#  'staffnurse': 11867,
#  'thornbury': 12555,
#  'osborne': 9319,
#  'rossendale': 10879,
#  'accrington': 189,
#  'caerphilly': 2088,
#  'orpington': 9308,
#  'fitness': 4865,
#  'specialist': 11760,
#  'swiis': 12208,
#  'remedy': 10590,
#  'lea': 7426,
#  'bridge': 1800,
#  'kilmarnock': 7145,
#  'wellington': 13463,
#  'emptylemon': 4296,
#  'tesco': 12476,
#  'occ': 9150,
#  'cherryred': 2553,
#  'facto': 4643,
#  'magenta': 7910,
#  'euro': 4480,
#  'graduate': 5484,
#  'fasttrack': 4714,
#  'crediton': 3287,
#  'placing': 9818,
#  'leaders': 7430,
#  'retailchoice': 10670,
#  'paul': 9523,
#  'davies': 3551,
#  'henry': 5988,
#  'fox': 5023,
#  'motorvation': 8634,
#  'prestige': 10033,
#  'fakenham': 4667,
#  'watton': 13397,
#  'asquith': 868,
#  'nurseries': 9095,
#  'mtrec': 8685,
#  'sykes': 12227,
#  'get': 5286,
#  'carter': 2297,
#  'wetherby': 13519,
#  'taste': 12337,
#  'pulse': 10220,
#  'collins': 2905,
#  'hindhead': 6090,
#  'wiveliscombe': 13695,
#  'ivybridge': 6741,
#  'radstock': 10339,
#  'ic': 6386,
#  'software': 11653,
#  'hanningfield': 5754,
#  'barker': 1172,
#  'ross': 10877,
#  'hpr': 6285,
#  'alton': 528,
#  'soloman': 11672,
#  'dune': 3981,
#  'sittingbourne': 11531,
#  'brand': 1741,
#  'republic': 10627,
#  'emo': 4280,
#  'information': 6512,
#  'technology': 12405,
#  '121': 6,
#  'facilities': 4640,
#  'sega': 11253,
#  'kensington': 7076,
#  'truro': 12867,
#  'skye': 11575,
#  'recruit': 10460,
#  'peoplecom': 9637,
#  'derry': 3675,
#  'source': 11707,
#  'yeadon': 13887,
#  'mobius': 8503,
#  'first': 4842,
#  'citizen': 2678,
#  'react': 10429,
#  'havant': 5856,
#  'workshop': 13775,
#  'anglo': 629,
#  'consult': 3057,
#  'sg': 11331,
#  ...}

# %% [markdown]
# #### 3. (1.5 балла) Обучите следующие модели на обучающей выборке:
#  - [логистическую регрессию](http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LogisticRegression.html) из модуля sklearn с параметрами по умолчанию;
#  - логистическую регрессию при помощи Vowpal Wabbit с параметрами по умолчанию.

# %%
from sklearn.linear_model import LogisticRegression
logreg = LogisticRegression(max_iter=2500)
logreg.fit(X_train, Y_train)
predicted = logreg.predict(X_test)
expected = Y_test
# Out:
#               precision    recall  f1-score   support
#
#            0       0.76      0.75      0.76     37940
#            1       0.74      0.75      0.75     35491
#
#     accuracy                           0.75     73431
#    macro avg       0.75      0.75      0.75     73431
# weighted avg       0.75      0.75      0.75     73431
#
# [[28562  9378]
#  [ 8840 26651]]

# %% [markdown]
# #### 4. (0.5 балла) Вычислите значения ROC-AUC, [F-меры](http://scikit-learn.org/stable/modules/generated/sklearn.metrics.f1_score.html), а также постройте [матрицу ошибок](http://scikit-learn.org/stable/modules/generated/sklearn.metrics.confusion_matrix.html) для каждой из построенных в п. 3 моделей на контрольной выборке. Сравните построенные модели по качеству их работы.

# %%
from sklearn import metrics

# summarize the fit of the model
print(metrics.classification_report(expected, predicted))
print(metrics.confusion_matrix(expected, predicted))

from sklearn.metrics import roc_curve as roc, auc, confusion_matrix, classification_report

r_x, r_y, _ = roc(Y_test, predicted)
plt.plot(r_x, r_y, label='ROC-AUC')
plt.plot([0, 1], [0, 1], linestyle='-', color="orange")
plt.legend(loc=0)
plt.show()
  
    
from mlxtend.plotting import plot_confusion_matrix

plot_confusion_matrix(confusion_matrix(predicted, Y_test), show_absolute=True, show_normed=True, colorbar=True)
plt.title("confusion matrix")
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#            0       0.76      0.75      0.76     37940
#            1       0.74      0.75      0.75     35491
#
#     accuracy                           0.75     73431
#    macro avg       0.75      0.75      0.75     73431
# weighted avg       0.75      0.75      0.75     73431
#
# [[28562  9378]
#  [ 8840 26651]]

# %% [markdown]
# #### 5. (1 балл) Отсортируйте веса признаков для модели логистической регрессии из scikit-learn, полученной в п. 2. Какие слова из встречающихся в выборке имеют наибольшее/наименьшее влияние на значение целевой переменной? Проинтерпретируйте полученный результат.

# %%
from sklearn.feature_selection import SelectFromModel

vect_values = vectorizer.vocabulary_.values()
vect_keys = vectorizer.vocabulary_.keys()

selector = SelectFromModel(estimator=LogisticRegression(max_iter=1000)).fit(X_train, Y_train)
d = {} 
for i in range(len(selector.estimator_.coef_[0])):
    d[i] = selector.estimator_.coef_[0][i]
sort_selector = {k: v for k, v in sorted(d.items(), key=lambda item: item[1], reverse=True)}
reverse_vector = dict(zip(vect_values, vect_keys))
for i in range(500):
    print(reverse_vector[list(sort_selector.keys())[i]], "      ", sort_selector[list(sort_selector.keys())[i]])
# Out:
# theladders        5.054390855622281
# admore        3.0468174489044735
# reeson        2.777186629420798
# mass        2.731274927658373
# rac        2.667784393040779
# linguistics        2.6152438136346925
# master        2.5969227556505095
# clemtech        2.5416975075052277
# psd        2.522915015801808
# michael        2.4920571672940035
# totallyexec        2.488544836955531
# annapurna        2.4495237614194587
# sanctuary        2.4486127253384553
# bskyb        2.4141781393173862
# server        2.4029316649788273
# a24        2.3479115140404687
# og        2.3404669235010296
# medicare        2.316957847860821
# medicspro        2.3157065040341096
# dreams        2.3111983472878546
# justgp        2.2504954497905234
# sporting        2.2035132608213313
# root        2.1969181619093656
# huntswood        2.187832293247719
# pk        2.1824320352624444
# hatstand        2.1589098005559118
# kenny        1.0324883253925867
# byron        1.032058718290359
# kyle        1.030039689222817
# 4it        1.0299723316437568
# covent        1.0282417926699043
# cornucopia        1.0274862727913996
# recruiters        1.0269255347330137
# epsilium        1.026389430669188
# department        1.0254252972868774
# staffworx        1.0250767140286838
# techconsult        1.0250532357541555
# edissero        1.0250217366557421
# land        1.024410485074893
# m2r        1.0237932498277142
# dmj        1.0233592942324898
# legalweekjobs        1.0223608669172628
# rhl        1.0221206467707458
# eyps        1.0218984713472887
# florit        1.0214477083780202
# mdm        1.020962397158085
# kleer        1.0199296260950301
# optic        1.0199296260950301
# facto        1.0198568416376799
# verticailty        1.0186774404447063
# ravendale        1.0169366971279787
# definitive        1.016488615125162
# barrington        1.016142624052611

# %% [markdown]
# #### 6. (0.5 доп. балла) Отсортируйте веса признаков для модели логистической регрессии, полученной в п. 2 при помощи Vowpal Wabbit. Какие слова из встречающихся в выборке имеют наибольшее/наименьшее влияние на значение целевой переменной? Проинтерпретирйте полученный результат.

# %%
# Your code here

# %% [markdown]
# ## TF-IDF
#
# Ещё один способ работы с текстовыми данными — [TF-IDF](https://en.wikipedia.org/wiki/Tf–idf) (**T**erm **F**requency–**I**nverse **D**ocument **F**requency). Рассмотрим коллекцию текстов $D$.  Для каждого уникального слова $t$ из документа $d \in D$ вычислим следующие величины:
#
# 1. Term Frequency – количество вхождений слова в отношении к общему числу слов в тексте:
# $$\text{tf}(t, d) = \frac{n_{td}}{\sum_{t \in d} n_{td}},$$
# где $n_{td}$ — количество вхождений слова $t$ в текст $d$.
# 1. Inverse Document Frequency
# $$\text{idf}(t, D) = \log \frac{\left| D \right|}{\left| \{d\in D: t \in d\} \right|},$$
# где $\left| \{d\in D: t \in d\} \right|$ – количество текстов в коллекции, содержащих слово $t$.
#
# Тогда для каждой пары (слово, текст) $(t, d)$ вычислим величину:
# $$\text{tf-idf}(t,d, D) = \text{tf}(t, d)\cdot \text{idf}(t, D).$$
#
# Отметим, что значение $\text{tf}(t, d)$ корректируется для часто встречающихся общеупотребимых слов при помощи значения $\text{idf}(t, D).$
#
# Признаковым описанием одного объекта $d \in D$ будет вектор $\bigg(\text{tf-idf}(t,d, D)\bigg)_{t\in V}$, где $V$ – словарь всех слов, встречающихся в коллекции $D$.
#
# #### 7. (0.5 балла) Создайте текстовое описание объектов обучающей и контрольной выборок, объединив значения всех признаков каждого объекта выборки через символы пробела. После этого получите признаковое описание объектов, вычислив вектор tf-idf для каждого объекта помощи [TfidfVectorizer](http://scikit-learn.org/stable/modules/generated/sklearn.feature_extraction.text.TfidfVectorizer.html), обучив его на обучающей выборке и применив на контрольной.

# %%
# Your code here

# %% [markdown]
# #### 8. (0 баллов) Обучите следующие модели на обучающей выборке:
# - [логистическую регрессию](http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LogisticRegression.html) из модуля sklearn с параметрами по умолчанию;
# - логистическую регрессию при помощи Vowpal Wabbit с параметрами по умолчанию.

# %%
# Your code here

# %% [markdown]
# #### 9. (0.5 балла) Вычислите значения ROC-AUC, [F-меры](http://scikit-learn.org/stable/modules/generated/sklearn.metrics.f1_score.html), а также постройте [матрицу ошибок](http://scikit-learn.org/stable/modules/generated/sklearn.metrics.confusion_matrix.html) для каждой из построенных в п. 8 моделей на контрольной выборке. Сравните построенные модели по качеству их работы.

# %%
# Your code here

# %% [markdown]
# #### 10. (0.5 балла) Сравните значения метрик из п. 9 со значениями, полученными в п. 5, и сравните соответствующие модели по качеству из работы.
#
# **Ответ**:

# %% [markdown]
# #### 11. (1 балл) Отсортируйте веса признаков для модели логистической регрессии из scikit-learn, полученной в п. 8. Какие слова из встречающихся в выборке имеют наибольшее/наименьшее влияние на значение целевой переменной? Проинтерпретирйте полученный результат.

# %%
# Your code here

# %% [markdown]
# #### 12. (0.5 доп. балла) Отсортируйте веса признаков для модели логистической регрессии, полученной в п. 8 при помощи Vowpal Wabbit. Какие слова из встречающихся в выборке имеют наибольшее/наименьшее влияние на значение целевой переменной? Проинтерпретирйте полученный результат.

# %%
# Your code here

# %% [markdown]
# ## Счётчики
#
# Ранее в рамках данного задания при построении моделей мы объединяли значения всех признаков в единую строку, что предполагает равноправность всех признаков. Однако заметим, что в этом случае мы допускаем потерю информации: слово "Glasgow" может по-разному влиять на зарплату, если оно находится в названии объявления и в геолокации. Чтобы устранить этот недостаток, при создании текстового описания объекта будем объединять только значения признаков Title и FullDescription, а остальные будем рассматривать как категориальные. При этом с полученным текстовым описанием объекта будем работать, как раньше (при помощи векторизации или tf-idf), а для кодирования категориальных признаков используем **счётчики**.
#
# Идея этого метода состоит в том, чтобы заменить значение категориального признака на вероятность того, что объект с данным значением признака относится к положительному классу. Опишем эту идею более формально. Пусть у нас есть выборка $X = \{ (x_i, y_i) \}_{i=1}^l,$ и $j$-ый признак принимает значения из множества $U_j = \{ u_{jn}\}_{n=1}^{N_j},$ где $N_j$ — количество различных значений $j$-ого признака. Пусть $x_{ij} = u_{j{n_{фроленков}}},$ тогда заменим значения $j$-ого категориального признака объекта $x_i$ на следующую оценку:
# $$\hat{P}(y_i=+1|x_{ij}=u_{jn}) = \frac{\sum_{m=1}^l \left[ x_{mj} = u_{jn} \right] \left[ y_m = +1 \right]}{\sum_{m=1}^l \left[ x_{mj} = u_{jn} \right]}.$$
#
# Однако заметим, что при таком способе формирования счётчиков мы учитываем в формуле для объекта $x_i$ его метку $y_i$, тем самым вносим информацию об ответе в признаки. Чтобы устранить этот недостаток, при вычислении счётчика будем исключать из рассмотрения текущий объект, т.е. рассматривать следующую оценку:
# $$\hat{P}(y_i=+1|X_{ij}=u_{jn}) = \frac{\sum_{m=1, \\ m \ne i}^l \left[ x_{mj} = u_{jn} \right] \left[ y_m = +1 \right]}{\sum_{m=1, \\ m \ne i}^l \left[ x_{mj} = u_{jn} \right]},$$
#
# #### 13. (0.5 балла) Создайте текстовое описание объектов обучающей и контрольной выборок, объединив значения признаков Title и FullDescription каждого объекта выборки через символ пробела, после чего перейдите к признаковому описанию объектов, вычислив вектор tf-idf аналогично п. 7.

# %%
columns = ['Title', 'FullDescription'] 

vectorizer = TfidfVectorizer()
X_train3, X_test3, _, _ = split(vectorizer, df, df_train, df_test, columns)

# %% [markdown]
# #### 14. (1 балл) Закодируйте категориальные признаки (все, кроме Title и FullDescription) при помощи [one-hot encoding](http://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.OneHotEncoder.html), после чего обучите логистическую регрессию (при помощи scikit-learn или Vowpal Wabbit) на обучающей выборке. Вычислите значения ROC-AUC, [F-меры](http://scikit-learn.org/stable/modules/generated/sklearn.metrics.f1_score.html), а также постройте [матрицу ошибок](http://scikit-learn.org/stable/modules/generated/sklearn.metrics.confusion_matrix.html) для полученной модели на контрольной выборке.

# %%
from sklearn.preprocessing import OneHotEncoder

columns = ['LocationNormalized', 'ContractType', 'ContractTime', 'Category', 'SourceName'] 

vectorizer = OneHotEncoder(sparse=False)
vectorizer.fit(df[columns].astype(str))
X_train4 = vectorizer.transform(df_train[columns].astype(str))
X_test4 = vectorizer.transform(df_test[columns].astype(str))

# %%
logreg = LogisticRegression(max_iter=1000)
lr_prediction4 = logreg.fit(X_train4, y_train).predict(X_test4)

# %%
roc_auc(y_test, lr_prediction4)
conf_matrix(y_test, lr_prediction4)
print("\n\t\tКраткая информация\n")
print(classification_report(y_test, lr_prediction4))

# %% [markdown]
# #### 15. (2 балла) Для выборки, полученной в п. 13, закодируйте категориальные признаки (все, кроме Title и FullDescription) при помощи счётчиков, после чего обучите логистическую регрессию (при помощи scikit-learn или Vowpal Wabbit) на обучающей выборке. Вычислите значения ROC-AUC, [F-меры](http://scikit-learn.org/stable/modules/generated/sklearn.metrics.f1_score.html), а также постройте [матрицу ошибок](http://scikit-learn.org/stable/modules/generated/sklearn.metrics.confusion_matrix.html) для полученной модели на контрольной выборке.
#
# Уделите внимание оптимальности вычисления счётчиков!

# %%
import scipy.sparse as sp
X_train5 = sp.hstack((sp.csr.csr_matrix(X_train4), X_train3), format='csr')
X_test5 = sp.hstack((sp.csr.csr_matrix(X_test4), X_test3), format='csr')

# %%
logreg = LogisticRegression(max_iter=1000)
lr_prediction5 = logreg.fit(X_train5, y_train).predict(X_test5)

# %%
roc_auc(y_test, lr_prediction5)
conf_matrix(y_test, lr_prediction5)
print("\n\t\tКраткая информация\n")
print(classification_report(y_test, lr_prediction5))

# %% [markdown]
# #### 16. (0.5 балла) Сравните значения метрик из п. 15 со значениями, полученными в п. 14, и сделайте вывод о качестве классификации для каждого из методов кодирования категориальных признаков.
#
# **Ответ:**

# %% [markdown]
# ## Подбор гиперпараметров
#
# #### 17. (1.5 доп. балла) Разбейте обучающую выборку, полученную в п. 13, на обучающую и валидационную в отношении 80/20, после чего подберите оптимальное количество фолдов, используемое при кодировании категориальных признаков (всех, кроме Title и FullDescription), путём оптимизации значения accuracy на валидационной выборке. Используйте следующие модели, аналогично также подобрав оптимальные значения указанных гиперпараметров:
# - логистическую регрессию из модуля sklearn с подбором коэффициента регуляризации;
# - логистическую регрессию при помощи Vowpal Wabbit с подбором следующих гиперпараметров:
#     - коэффициент регуляризации (--l2);
#     - количество эпох (--passes);
#     - длина градиентного шага (-l);
#     - длина N-грамм (--ngram).

# %%
# Your code here

# %% [markdown]
# #### 18. (0.5 доп. балла) Обучите указанные выше модели на обучающей выборке для оптимальных значений гиперпараметров, найденных в п. 17, после чего для каждой из моделей вычислите значения ROC-AUC, F-меры, а также постройте матрицу ошибок на контрольной выборке. Как качество классификации при помощи полученных в данном разделе моделей соотносится с моделями, полученными в предыдущих разделах?

# %%
# Your code here

# %% [markdown]
# Здесь вы можете поделиться своими мыслями по поводу этого задания.

# %% [markdown]
# А здесь — вставить вашу вторую любимую смешную картинку.

# %% [markdown]
# А здесь — посоветовать преподавателям хороший фильм или сериал.
